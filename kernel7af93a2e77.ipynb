# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from zipfile import ZipFile 
from subprocess import check_output
# print(check_output(["ls", "../input/fluctuation/"]).decode("utf8"))



# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os
from sympy import *

print(os.listdir("../input/fluctuation/fluctuation/fluctuation/"))

# Any results you write to the current directory are saved as output.
# Out:
# ['fluctuation_65.csv', 'fluctuation_5.csv', 'fluctuation_49.csv', 'fluctuation_83.csv', 'fluctuation_90.csv', 'fluctuation_41.csv', 'fluctuation_16.csv', 'fluctuation_12.csv', 'fluctuation_28.csv', 'fluctuation_25.csv', 'fluctuation_62.csv', 'fluctuation_10.csv', 'fluctuation_17.csv', 'fluctuation_54.csv', 'fluctuation_96.csv', 'fluctuation_50.csv', 'fluctuation_18.csv', 'fluctuation_24.csv', 'fluctuation_40.csv', 'fluctuation_45.csv', 'fluctuation_91.csv', 'fluctuation_56.csv', 'fluctuation_8.csv', 'fluctuation_55.csv', 'fluctuation_33.csv', 'fluctuation_51.csv', 'fluctuation_88.csv', 'fluctuation_75.csv', 'fluctuation_78.csv', 'fluctuation_0.csv', 'fluctuation_92.csv', 'fluctuation_77.csv', 'fluctuation_43.csv', 'fluctuation_34.csv', 'fluctuation_2.csv', 'fluctuation_74.csv', 'fluctuation_4.csv', 'fluctuation_13.csv', 'fluctuation_69.csv', 'fluctuation_64.csv', 'fluctuation_84.csv', 'fluctuation_32.csv', 'fluctuation_94.csv', 'fluctuation_20.csv', 'fluctuation_9.csv', 'fluctuation_39.csv', 'fluctuation_29.csv', 'fluctuation_37.csv', 'fluctuation_99.csv', 'fluctuation_89.csv', 'fluctuation_71.csv', 'fluctuation_58.csv', 'fluctuation_66.csv', 'fluctuation_68.csv', 'fluctuation_76.csv', 'fluctuation_36.csv', 'fluctuation_35.csv', 'fluctuation_95.csv', 'fluctuation_81.csv', 'fluctuation_79.csv', 'fluctuation_23.csv', 'fluctuation_60.csv', 'fluctuation_63.csv', 'fluctuation_31.csv', 'fluctuation_61.csv', 'fluctuation_73.csv', 'fluctuation_59.csv', 'fluctuation_70.csv', 'fluctuation_85.csv', 'fluctuation_7.csv', 'fluctuation_87.csv', 'fluctuation_46.csv', 'fluctuation_6.csv', 'fluctuation_97.csv', 'fluctuation_93.csv', 'fluctuation_22.csv', 'fluctuation_86.csv', 'fluctuation_21.csv', 'fluctuation_53.csv', 'fluctuation_44.csv', 'fluctuation_27.csv', 'fluctuation_67.csv', 'fluctuation_38.csv', 'fluctuation_15.csv', 'fluctuation_52.csv', 'fluctuation_57.csv', 'fluctuation_30.csv', 'fluctuation_1.csv', 'fluctuation_72.csv', 'fluctuation_47.csv', 'fluctuation_19.csv', 'fluctuation_48.csv', 'fluctuation_11.csv', 'fluctuation_42.csv', 'fluctuation_82.csv', 'fluctuation_80.csv', 'fluctuation_3.csv', 'fluctuation_14.csv', 'fluctuation_26.csv', 'fluctuation_98.csv']

# %%
grid_df = pd.read_csv('../input//dns-grid/dns.csv', header =None)
data = pd.DataFrame(columns = ['X', 'Y', 'uV_mean', 'ux', 'uy', 'mu_t'])
sum=0
dx = 0.5
dy = 0.5
time_steps = 100
# print (grid_df.head)

# %%
for i in range(4001, 8000):
    sum = 0
    for filename in os.listdir("../input/fluctuation/fluctuation/fluctuation/"):
        df = pd.read_csv('../input/fluctuation/fluctuation/fluctuation/'+filename)
        sum = sum+(df.iloc[i,1]*df.iloc[i,2])
        if (i==0):
            uy = (df.iloc[i+1,1]-df.iloc[i,1])/(2*dy)
            vx = (df.iloc[i+1,2]-df.iloc[i,2])/(2*dx)
        elif(i==len(grid_df)-1):
            uy = (df.iloc[i-1,1]-df.iloc[i,1])/(2*dy)
            vx = (df.iloc[i-1,2]-df.iloc[i,2])/(2*dx)
        else:
            uy = (df.iloc[i+1,1]-df.iloc[i-1,1])/(2*dy)
            vx = (df.iloc[i+1,2]-df.iloc[i-1,2])/(2*dx)
    uv_mean = sum/time_steps
    mu_t = uv_mean/(uy+vx)
    X,Y = grid_df.iloc[i,0], grid_df.iloc[i,1]
    data.loc[len(data)] = X, Y, uv_mean,uy,vx, mu_t

    # name = 
    if (i % 100 == 0):
        print(str(i) + " Done")
        data.to_csv("mut.csv")
data.to_csv("mut.csv")
# Out:
# 4100 Done
# 4200 Done
# 4300 Done
